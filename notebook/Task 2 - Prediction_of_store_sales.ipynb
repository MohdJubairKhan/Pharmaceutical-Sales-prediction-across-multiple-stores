# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. train_data

# %%
train_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/project-6(Pharmaceutical Sales)/data/cleaned_train_data.csv')

# %%
train_data.head(5)
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      5          5  2015-07-31   4822        559     1      1            0
# 4      6          5  2015-07-31   5651        589     1      1            0
#
#    SchoolHoliday  Holiday  Day  Month  Year
# 0              1        1   31      7  2015
# 1              1        1   31      7  2015
# 2              1        1   31      7  2015
# 3              1        1   31      7  2015
# 4              1        1   31      7  2015

# %%
train_data.shape
# Out:
# (968510, 13)

# %% [markdown]
# # 2. test_data

# %%
test_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/project-6(Pharmaceutical Sales)/data/cleaned_test_data.csv')

# %%
test_data.head(5)
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0
#
#    Holiday  Day  Month  Year
# 0        0   17      9  2015
# 1        0   17      9  2015
# 2        0   17      9  2015
# 3        0   17      9  2015
# 4        0   17      9  2015

# %%
test_data.shape
# Out:
# (41088, 12)

# %% [markdown]
# # 3. Store_data

# %%
store_data = pd.read_csv(r'C:/Users/Hp/Desktop/Data_Science_Jupyter/project-6(Pharmaceutical Sales)/data/cleaned_store_data.csv')

# %%
store_data.head(5)
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      6         a          a                310.0                       12.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0             22.0           2012.0
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0             22.0           2012.0
# 4                    2013.0       0             22.0           2012.0
#
#      PromoInterval
# 0          Unknown
# 1  Jan,Apr,Jul,Oct
# ...

# %%
store_data.shape
# Out:
# (1007, 10)

# %% [markdown]
# # Merging 'train.csv' and 'store.csv'

# %%
train_store_data = pd.merge(train_data, store_data, how = 'inner', on = 'Store')

# %%
train_store_data.head(5)
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      6          5  2015-07-31   5651        589     1      1            0
# 4      8          5  2015-07-31   8492        833     1      1            0
#
#    SchoolHoliday  Holiday  ...  Year  StoreType  Assortment  \
# 0              1        1  ...  2015          c           a
# 1              1        1  ...  2015          a           a
# 2              1        1  ...  2015          a           a
# 3              1        1  ...  2015          a           a
# 4              1        1  ...  2015          a           a
#
#   CompetitionDistance CompetitionOpenSinceMonth  CompetitionOpenSinceYear  \
# ...

# %% [markdown]
# # Merging 'test.csv' and 'store.csv'

# %%
test_store_data = pd.merge(test_data, store_data, how = 'inner', on = 'Store')

# %%
test_store_data.head(5)
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   4      8          4  2015-09-17   1.0      1            0              0
# 3   5      9          4  2015-09-17   1.0      1            0              0
# 4   6     10          4  2015-09-17   1.0      1            0              0
#
#    Holiday  Day  ...  Year  StoreType Assortment CompetitionDistance  \
# 0        0   17  ...  2015          c          a              1270.0
# 1        0   17  ...  2015          a          a             14130.0
# 2        0   17  ...  2015          a          a              7520.0
# 3        0   17  ...  2015          a          c              2030.0
# 4        0   17  ...  2015          a          a              3160.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# ...

# %% [markdown]
# # 2.1 Preprocessing

# %% [markdown]
# # Convert Non-Numeric Columns to Numeric

# %%
# One-hot encode categorical columns on train_store_data
train_store_data = pd.get_dummies(train_store_data, columns=['StateHoliday', 'StoreType', 'Assortment', 'PromoInterval'], drop_first=True,dtype=int)

# %%
train_store_data.sample(5)
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 72488     762          7  2015-05-17      0          0     0      0
# 862343   1061          5  2013-01-11   6354        484     1      1
# 790052    103          2  2013-03-26      0          0     0      1
# 849521    902          4  2013-01-24   4676        635     1      1
# 518507    653          7  2014-01-05      0          0     0      0
#
#         SchoolHoliday  Holiday  Day  ...  StateHoliday_b  StateHoliday_c  \
# 72488               0        0   17  ...               0               0
# 862343              0        0   11  ...               0               0
# 790052              1        1   26  ...               0               0
# 849521              0        0   24  ...               0               0
# 518507              0        0    5  ...               0               0
#
#         StoreType_b  StoreType_c  StoreType_d  Assortment_b  Assortment_c  \
# ...

# %%
# One-hot encode categorical columns on train_store_data
test_store_data = pd.get_dummies(test_store_data, columns=['PromoInterval','Assortment','StoreType','StateHoliday'], drop_first=True,dtype=int)

# %%
test_store_data.sample(5)
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo  SchoolHoliday  \
# 25951  28229   1091          7  2015-08-16   0.0      0              0
# 4532    4936    852          6  2015-09-12   1.0      0              0
# 6450    7025    230          3  2015-09-09   1.0      0              0
# 5887    6412    543          4  2015-09-10   1.0      0              0
# 1308    1426    736          3  2015-09-16   1.0      1              0
#
#        Holiday  Day  Month  ...  Promo2SinceYear  \
# 25951        0   16      8  ...           2012.0
# 4532         0   12      9  ...           2011.0
# 6450         0    9      9  ...           2012.0
# 5887         0   10      9  ...           2012.0
# 1308         0   16      9  ...           2011.0
#
#        PromoInterval_Jan,Apr,Jul,Oct  PromoInterval_Mar,Jun,Sept,Dec  \
# 25951                              0                               0
# 4532                               1                               0
# ...
